# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
from datetime import datetime

# %%
weather1 = pd.read_csv('../data/df_weather1.csv')
weather1.head()
# Out:
#    Unnamed: 0   Date Daily Rainfall Total (mm) Highest 30-min Rainfall (mm)  \
# 0           0  1 Oct                      22.6                         18.6
# 1           1  2 Oct                      16.4                         13.2
# 2           2  3 Oct                      44.2                         18.6
# 3           3  4 Oct                       1.4                          1.0
# 4           4  5 Oct                      49.2                         17.6
#
#   Highest 60-min Rainfall (mm) Highest 120-min Rainfall (mm)  \
# 0                         21.4                          21.4
# 1                         14.2                          16.0
# 2                         33.4                          39.6
# 3                          1.2                           1.2
# 4                         29.2                          44.8
#
#   Mean Temperature (°C) Maximum Temperature (°C) Minimum Temperature (°C)  \
# 0                  26.8                     31.8                     24.4
# 1                  27.1                     32.6                     23.0
# 2                  26.3                     31.8                     23.1
# 3                  26.2                     31.2                     24.5
# 4                  26.0                     28.6                     22.8
#
#   Mean Wind Speed (km/h) Max Wind Speed (km/h)  year     region
# 0                    6.0                  27.8  2022  Admiralty
# 1                    5.8                  24.4  2022  Admiralty
# 2                    5.7                  52.6  2022  Admiralty
# 3                    6.3                  36.3  2022  Admiralty
# 4                    7.2                  33.5  2022  Admiralty

# %%
weather1.shape
# Out:
# (66426, 13)

# %%
weather2 = pd.read_csv('../data/df_weather2.csv')
weather2.head()
# Out:
#    Unnamed: 0   Date Daily Rainfall Total (mm) Highest 30-min Rainfall (mm)  \
# 0           0  1 Oct                      17.0                          8.0
# 1           1  2 Oct                      32.2                         10.6
# 2           2  3 Oct                      10.4                          4.8
# 3           3  4 Oct                       9.8                          5.2
# 4           4  5 Oct                      49.4                         36.2
#
#   Highest 60-min Rainfall (mm) Highest 120-min Rainfall (mm)  \
# 0                         10.4                          13.2
# 1                         12.6                          17.4
# 2                          5.8                           7.4
# 3                          8.8                           9.8
# 4                         42.8                          46.6
#
#   Mean Temperature (°C) Maximum Temperature (°C) Minimum Temperature (°C)  \
# 0                     -                        -                        -
# 1                     -                        -                        -
# 2                     -                        -                        -
# 3                     -                        -                        -
# 4                     -                        -                        -
#
#   Mean Wind Speed (km/h) Max Wind Speed (km/h)  year         region
# 0                      -                     -  2022  Marine Parade
# 1                      -                     -  2022  Marine Parade
# 2                      -                     -  2022  Marine Parade
# 3                      -                     -  2022  Marine Parade
# 4                      -                     -  2022  Marine Parade

# %%
weather2.shape
# Out:
# (64744, 13)

# %%
# concat weather1 and weather2
weather = pd.concat([weather1,weather2])
weather.head()
# Out:
#    Unnamed: 0   Date Daily Rainfall Total (mm) Highest 30-min Rainfall (mm)  \
# 0           0  1 Oct                      22.6                         18.6
# 1           1  2 Oct                      16.4                         13.2
# 2           2  3 Oct                      44.2                         18.6
# 3           3  4 Oct                       1.4                          1.0
# 4           4  5 Oct                      49.2                         17.6
#
#   Highest 60-min Rainfall (mm) Highest 120-min Rainfall (mm)  \
# 0                         21.4                          21.4
# 1                         14.2                          16.0
# 2                         33.4                          39.6
# 3                          1.2                           1.2
# 4                         29.2                          44.8
#
#   Mean Temperature (°C) Maximum Temperature (°C) Minimum Temperature (°C)  \
# 0                  26.8                     31.8                     24.4
# 1                  27.1                     32.6                     23.0
# 2                  26.3                     31.8                     23.1
# 3                  26.2                     31.2                     24.5
# 4                  26.0                     28.6                     22.8
#
#   Mean Wind Speed (km/h) Max Wind Speed (km/h)  year     region
# 0                    6.0                  27.8  2022  Admiralty
# 1                    5.8                  24.4  2022  Admiralty
# 2                    5.7                  52.6  2022  Admiralty
# 3                    6.3                  36.3  2022  Admiralty
# 4                    7.2                  33.5  2022  Admiralty

# %%
weather.shape
# Out:
# (131170, 13)

# %%
# remove unnamed column
weather.drop(columns=['Unnamed: 0'], inplace=True)
weather.head()
# Out:
#     Date Daily Rainfall Total (mm) Highest 30-min Rainfall (mm)  \
# 0  1 Oct                      22.6                         18.6
# 1  2 Oct                      16.4                         13.2
# 2  3 Oct                      44.2                         18.6
# 3  4 Oct                       1.4                          1.0
# 4  5 Oct                      49.2                         17.6
#
#   Highest 60-min Rainfall (mm) Highest 120-min Rainfall (mm)  \
# 0                         21.4                          21.4
# 1                         14.2                          16.0
# 2                         33.4                          39.6
# 3                          1.2                           1.2
# 4                         29.2                          44.8
#
#   Mean Temperature (°C) Maximum Temperature (°C) Minimum Temperature (°C)  \
# 0                  26.8                     31.8                     24.4
# 1                  27.1                     32.6                     23.0
# 2                  26.3                     31.8                     23.1
# 3                  26.2                     31.2                     24.5
# 4                  26.0                     28.6                     22.8
#
#   Mean Wind Speed (km/h) Max Wind Speed (km/h)  year     region
# 0                    6.0                  27.8  2022  Admiralty
# 1                    5.8                  24.4  2022  Admiralty
# 2                    5.7                  52.6  2022  Admiralty
# 3                    6.3                  36.3  2022  Admiralty
# 4                    7.2                  33.5  2022  Admiralty

# %% [markdown]
# #change column name to lowercase and replace 'space' with 'underscore'
# weather.columns = weather.columns.str.replace(' ', '_').str.lower()
# weather.head()

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131170 entries, 0 to 131169
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Date                           131170 non-null  object
#  1   Daily Rainfall Total (mm)      131170 non-null  object
#  2   Highest 30-min Rainfall (mm)   131170 non-null  object
#  3   Highest 60-min Rainfall (mm)   131170 non-null  object
#  4   Highest 120-min Rainfall (mm)  131170 non-null  object
#  5   Mean Temperature (°C)          131170 non-null  object
#  6   Maximum Temperature (°C)       130935 non-null  object
#  7   Minimum Temperature (°C)       130935 non-null  object
#  8   Mean Wind Speed (km/h)         131170 non-null  object
#  9   Max Wind Speed (km/h)          130930 non-null  object
#  10  year                           131170 non-null  int64
#  11  region                         131170 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 12.0+ MB

# %%
# check for null
weather.isnull().sum()
# Out:
# Date                               0
# Daily Rainfall Total (mm)          0
# Highest 30-min Rainfall (mm)       0
# Highest 60-min Rainfall (mm)       0
# Highest 120-min Rainfall (mm)      0
# Mean Temperature (°C)              0
# Maximum Temperature (°C)         235
# Minimum Temperature (°C)         235
# Mean Wind Speed (km/h)             0
# Max Wind Speed (km/h)            240
# year                               0
# region                             0
# dtype: int64

# %%
# drop null as it is less than 5% of whole dataset
weather.dropna(inplace=True)

# %%
weather.isnull().sum()
# Out:
# Date                             0
# Daily Rainfall Total (mm)        0
# Highest 30-min Rainfall (mm)     0
# Highest 60-min Rainfall (mm)     0
# Highest 120-min Rainfall (mm)    0
# Mean Temperature (°C)            0
# Maximum Temperature (°C)         0
# Minimum Temperature (°C)         0
# Mean Wind Speed (km/h)           0
# Max Wind Speed (km/h)            0
# year                             0
# region                           0
# dtype: int64

# %%
weather.apply(lambda col: col.str.contains('-'), axis=1).sum()
# Out:
# Date                                 0.0
# Daily Rainfall Total (mm)         2801.0
# Highest 30-min Rainfall (mm)      3416.0
# Highest 60-min Rainfall (mm)      3513.0
# Highest 120-min Rainfall (mm)     3510.0
# Mean Temperature (°C)            32456.0
# Maximum Temperature (°C)         31345.0
# Minimum Temperature (°C)         31373.0
# Mean Wind Speed (km/h)           32750.0
# Max Wind Speed (km/h)            31865.0
# year                                 0.0
# region                               0.0
# dtype: float64

# %%
# replace '-' with '0'
weather.apply(lambda col: col.replace('—','0.0'), axis=1)
# Out:
#           Date Daily Rainfall Total (mm) Highest 30-min Rainfall (mm)  \
# 0        1 Oct                      22.6                         18.6
# 1        2 Oct                      16.4                         13.2
# 2        3 Oct                      44.2                         18.6
# 3        4 Oct                       1.4                          1.0
# 4        5 Oct                      49.2                         17.6
# ...        ...                       ...                          ...
# 131165  27 Jan                       0.0                          0.0
# 131166  28 Jan                      15.4                          9.2
# 131167  29 Jan                       1.4                          1.0
# 131168  30 Jan                       0.0                          0.0
# 131169  31 Jan                       0.0                          0.0
#
#        Highest 60-min Rainfall (mm) Highest 120-min Rainfall (mm)  \
# 0                              21.4                          21.4
# 1                              14.2                          16.0
# 2                              33.4                          39.6
# 3                               1.2                           1.2
# 4                              29.2                          44.8
# ...                             ...                           ...
# 131165                          0.0                           0.0
# 131166                         10.8                          14.8
# 131167                          1.0                           1.4
# 131168                          0.0                           0.0
# 131169                          0.0                           0.0
#
#        Mean Temperature (°C) Maximum Temperature (°C)  \
# 0                       26.8                     31.8
# 1                       27.1                     32.6
# 2                       26.3                     31.8
# 3                       26.2                     31.2
# 4                       26.0                     28.6
# ...                      ...                      ...
# 131165                   0.0                      0.0
# 131166                   0.0                      0.0
# 131167                   0.0                      0.0
# 131168                   0.0                      0.0
# 131169                   0.0                      0.0
#
#        Minimum Temperature (°C) Mean Wind Speed (km/h) Max Wind Speed (km/h)  \
# 0                          24.4                    6.0                  27.8
# 1                          23.0                    5.8                  24.4
# 2                          23.1                    5.7                  52.6
# 3                          24.5                    6.3                  36.3
# 4                          22.8                    7.2                  33.5
# ...                         ...                    ...                   ...
# 131165                      0.0                    0.0                   0.0
# 131166                      0.0                    0.0                   0.0
# 131167                      0.0                    0.0                   0.0
# 131168                      0.0                    0.0                   0.0
# 131169                      0.0                    0.0                   0.0
#
#         year     region
# 0       2022  Admiralty
# 1       2022  Admiralty
# 2       2022  Admiralty
# 3       2022  Admiralty
# 4       2022  Admiralty
# ...      ...        ...
# 131165  2016     Yishun
# 131166  2016     Yishun
# 131167  2016     Yishun
# 131168  2016     Yishun
# 131169  2016     Yishun
#
# [130926 rows x 12 columns]

# %%
weather.tail()
# Out:
#           Date Daily Rainfall Total (mm) Highest 30-min Rainfall (mm)  \
# 131165  27 Jan                       0.0                          0.0
# 131166  28 Jan                      15.4                          9.2
# 131167  29 Jan                       1.4                          1.0
# 131168  30 Jan                       0.0                          0.0
# 131169  31 Jan                       0.0                          0.0
#
#        Highest 60-min Rainfall (mm) Highest 120-min Rainfall (mm)  \
# 131165                          0.0                           0.0
# 131166                         10.8                          14.8
# 131167                          1.0                           1.4
# 131168                          0.0                           0.0
# 131169                          0.0                           0.0
#
#        Mean Temperature (°C) Maximum Temperature (°C)  \
# 131165                     —                        —
# 131166                     —                        —
# 131167                     —                        —
# 131168                     —                        —
# 131169                     —                        —
#
#        Minimum Temperature (°C) Mean Wind Speed (km/h) Max Wind Speed (km/h)  \
# 131165                        —                      —                     —
# 131166                        —                      —                     —
# 131167                        —                      —                     —
# 131168                        —                      —                     —
# 131169                        —                      —                     —
#
#         year  region
# 131165  2016  Yishun
# 131166  2016  Yishun
# 131167  2016  Yishun
# 131168  2016  Yishun
# 131169  2016  Yishun

# %%
weather[['Daily Rainfall Total (mm)',\
         'Highest 30-min Rainfall (mm)',\
         'Highest 60-min Rainfall (mm)',\
         'Highest 120-min Rainfall (mm)',\
         'Mean Temperature (°C)',\
         'Maximum Temperature (°C)',\
         'Minimum Temperature (°C)',\
         'Mean Wind Speed (km/h)',\
         'Max Wind Speed (km/h)']] = weather[['Daily Rainfall Total (mm)',\
         'Highest 30-min Rainfall (mm)',\
         'Highest 60-min Rainfall (mm)',\
         'Highest 120-min Rainfall (mm)',\
         'Mean Temperature (°C)',\
         'Maximum Temperature (°C)',\
         'Minimum Temperature (°C)',\
         'Mean Wind Speed (km/h)',\
         'Max Wind Speed (km/h)']].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [41], in <cell line: 9>()
#       1 weather[['Daily Rainfall Total (mm)',\
#       2          'Highest 30-min Rainfall (mm)',\
#       3          'Highest 60-min Rainfall (mm)',\
#       4          'Highest 120-min Rainfall (mm)',\
#       5          'Mean Temperature (°C)',\
#       6          'Maximum Temperature (°C)',\
#       7          'Minimum Temperature (°C)',\
#       8          'Mean Wind Speed (km/h)',\
# ----> 9          'Max Wind Speed (km/h)']] = weather[['Daily Rainfall Total (mm)',\
#      10          'Highest 30-min Rainfall (mm)',\
#      11          'Highest 60-min Rainfall (mm)',\
#      12          'Highest 120-min Rainfall (mm)',\
#      13          'Mean Temperature (°C)',\
#      14          'Maximum Temperature (°C)',\
#      15          'Minimum Temperature (°C)',\
#      16          'Mean Wind Speed (km/h)',\
#      17          'Max Wind Speed (km/h)']].astype(float)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1098, in astype_nansafe(arr, dtype, copy, skipna)
#    1096 if arr.ndim > 1:
#    1097     flat = arr.ravel()
# -> 1098     result = astype_nansafe(flat, dtype, copy=copy, skipna=skipna)
#    1099     # error: Item "ExtensionArray" of "Union[ExtensionArray, ndarray]" has no
#    1100     # attribute "reshape"
#    1101     return result.reshape(arr.shape)  # type: ignore[union-attr]
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1181, in astype_nansafe(arr, dtype, copy, skipna)
#    1177     raise ValueError(msg)
#    1179 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1180     # Explicit copy, or required since NumPy can't view from / to object.
# -> 1181     return arr.astype(dtype, copy=True)
#    1183 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '-'

# %%
# save data
weather.to_csv('../data/weather.csv', index=False)
